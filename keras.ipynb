# %% [markdown]
# # Keras Lesson

# %% [markdown]
# ## Sequential NN

# %%
# import warnings
import warnings
warnings.filterwarnings('ignore')

from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.utils import np_utils
from sklearn.preprocessing import LabelEncoder
from sklearn import datasets
from sklearn.model_selection import train_test_split

iris = datasets.load_iris()
X, y = iris.data, iris.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

y_train_one_hot = np_utils.to_categorical(y_train)
y_test_one_hot = np_utils.to_categorical(y_test)

print(y_train[0:3])
print(y_train_one_hot[0:3])

model = Sequential()
model.add(Dense(16, input_shape=(4,)))
model.add(Activation('sigmoid'))
model.add(Dense(3))
model.add(Activation('softmax'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=["accuracy"])
model.fit(X_train, y_train_one_hot, epochs=100, batch_size=1, verbose=0);
loss, accuracy = model.evaluate(X_test, y_test_one_hot, verbose=0)
print("Accuracy = {:.2f}".format(accuracy))
# Out:
# [1 2 2]
# [[0. 1. 0.]
#  [0. 0. 1.]
#  [0. 0. 1.]]
# Accuracy = 0.98

# %% [markdown]
# ## Shallow Sequential NN

# %%
model_new = Sequential()
model_new.add(Dense(3, input_shape=(4,)))
model_new.add(Activation('softmax'))
model_new.compile(optimizer='adam', loss='categorical_crossentropy', metrics=["accuracy"])
model_new.fit(X_train, y_train_one_hot, epochs=100, batch_size=1, verbose=1);
loss, accuracy = model_new.evaluate(X_test, y_test_one_hot, verbose=0)
print("Accuracy = {:.2f}".format(accuracy))
# Out:
# Epoch 1/100
# 105/105 [==============================] - 1s 5ms/step - loss: 5.5153 - acc: 0.3238
# Epoch 2/100
# 105/105 [==============================] - 0s 1ms/step - loss: 4.2916 - acc: 0.1143
# Epoch 3/100
# 105/105 [==============================] - 0s 1ms/step - loss: 3.4118 - acc: 0.0000e+00
# Epoch 4/100
# 105/105 [==============================] - 0s 1ms/step - loss: 2.8236 - acc: 0.0381
# Epoch 5/100
# 105/105 [==============================] - 0s 1ms/step - loss: 2.3765 - acc: 0.1524
# Epoch 6/100
# 105/105 [==============================] - 0s 1ms/step - loss: 1.9840 - acc: 0.2000
# Epoch 7/100
# 105/105 [==============================] - 0s 1ms/step - loss: 1.6520 - acc: 0.2286
# Epoch 8/100
# 105/105 [==============================] - 0s 1ms/step - loss: 1.4302 - acc: 0.2857
# Epoch 9/100
# 105/105 [==============================] - 0s 1ms/step - loss: 1.3180 - acc: 0.2476
# Epoch 10/100
# 105/105 [==============================] - 0s 1ms/step - loss: 1.2452 - acc: 0.2667
# Epoch 11/100
# 105/105 [==============================] - 0s 1ms/step - loss: 1.1895 - acc: 0.0952
# Epoch 12/100
# 105/105 [==============================] - 0s 1ms/step - loss: 1.1407 - acc: 0.1429
# Epoch 13/100
# 105/105 [==============================] - 0s 1ms/step - loss: 1.0920 - acc: 0.1810
# Epoch 14/100
# 105/105 [==============================] - 0s 1ms/step - loss: 1.0516 - acc: 0.2381
# Epoch 15/100
# 105/105 [==============================] - 0s 1ms/step - loss: 1.0100 - acc: 0.3524
# Epoch 16/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.9722 - acc: 0.2952
# Epoch 17/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.9305 - acc: 0.4857
# Epoch 18/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.9029 - acc: 0.5238
# Epoch 19/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.8690 - acc: 0.5524
# Epoch 20/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.8424 - acc: 0.6190
# Epoch 21/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.8168 - acc: 0.6476
# Epoch 22/100
# 105/105 [==============================] - 0s 2ms/step - loss: 0.7888 - acc: 0.6667
# Epoch 23/100
# 105/105 [==============================] - 0s 2ms/step - loss: 0.7650 - acc: 0.7048
# Epoch 24/100
# 105/105 [==============================] - 0s 2ms/step - loss: 0.7433 - acc: 0.7143
# Epoch 25/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.7245 - acc: 0.7048
# Epoch 26/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.7095 - acc: 0.7143
# Epoch 27/100
# 105/105 [==============================] - 0s 2ms/step - loss: 0.6884 - acc: 0.7048
# Epoch 28/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.6765 - acc: 0.6952
# Epoch 29/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.6616 - acc: 0.7333
# Epoch 30/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.6468 - acc: 0.6952
# Epoch 31/100
# 105/105 [==============================] - 0s 2ms/step - loss: 0.6291 - acc: 0.7048
# Epoch 32/100
# 105/105 [==============================] - 0s 2ms/step - loss: 0.6167 - acc: 0.7429
# Epoch 33/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.6063 - acc: 0.7333
# Epoch 34/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.5982 - acc: 0.7048
# Epoch 35/100
# 105/105 [==============================] - 0s 2ms/step - loss: 0.5847 - acc: 0.7429
# Epoch 36/100
# 105/105 [==============================] - 0s 2ms/step - loss: 0.5722 - acc: 0.7333
# Epoch 37/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.5665 - acc: 0.8000
# Epoch 38/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.5576 - acc: 0.7048
# Epoch 39/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.5494 - acc: 0.7238
# Epoch 40/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.5395 - acc: 0.8190
# Epoch 41/100
# 105/105 [==============================] - 0s 2ms/step - loss: 0.5299 - acc: 0.7905
# Epoch 42/100
# 105/105 [==============================] - 0s 2ms/step - loss: 0.5246 - acc: 0.7429
# Epoch 43/100
# 105/105 [==============================] - 0s 2ms/step - loss: 0.5176 - acc: 0.7619
# Epoch 44/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.5101 - acc: 0.7905
# Epoch 45/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.5025 - acc: 0.8190
# Epoch 46/100
# 105/105 [==============================] - 0s 2ms/step - loss: 0.4962 - acc: 0.7714
# Epoch 47/100
# 105/105 [==============================] - 0s 2ms/step - loss: 0.4896 - acc: 0.8095
# Epoch 48/100
# 105/105 [==============================] - 0s 2ms/step - loss: 0.4842 - acc: 0.7810
# Epoch 49/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.4786 - acc: 0.8190
# Epoch 50/100
# 105/105 [==============================] - 0s 2ms/step - loss: 0.4719 - acc: 0.7619
# Epoch 51/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.4667 - acc: 0.8571
# Epoch 52/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.4630 - acc: 0.7714
# Epoch 53/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.4559 - acc: 0.8762
# Epoch 54/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.4532 - acc: 0.8286
# Epoch 55/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.4465 - acc: 0.7905
# Epoch 56/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.4411 - acc: 0.8286
# Epoch 57/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.4424 - acc: 0.8286
# Epoch 58/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.4381 - acc: 0.8476
# Epoch 59/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.4320 - acc: 0.9143
# Epoch 60/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.4256 - acc: 0.8286
# Epoch 61/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.4200 - acc: 0.8952
# Epoch 62/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.4188 - acc: 0.8952
# Epoch 63/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.4131 - acc: 0.8381
# Epoch 64/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.4080 - acc: 0.8381
# Epoch 65/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.4071 - acc: 0.8857
# Epoch 66/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.4020 - acc: 0.9048
# Epoch 67/100
# 105/105 [==============================] - 0s 2ms/step - loss: 0.3989 - acc: 0.9238
# Epoch 68/100
# 105/105 [==============================] - 0s 2ms/step - loss: 0.3964 - acc: 0.8381
# Epoch 69/100
# 105/105 [==============================] - 0s 2ms/step - loss: 0.3925 - acc: 0.9143
# Epoch 70/100
# 105/105 [==============================] - 0s 2ms/step - loss: 0.3900 - acc: 0.8476
# Epoch 71/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.3887 - acc: 0.8762
# Epoch 72/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.3830 - acc: 0.9619
# Epoch 73/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.3804 - acc: 0.8667
# Epoch 74/100
# 105/105 [==============================] - 0s 2ms/step - loss: 0.3777 - acc: 0.9333
# Epoch 75/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.3733 - acc: 0.8952
# Epoch 76/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.3730 - acc: 0.8857
# Epoch 77/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.3661 - acc: 0.9524
# Epoch 78/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.3643 - acc: 0.9333
# Epoch 79/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.3609 - acc: 0.9143
# Epoch 80/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.3614 - acc: 0.9429
# Epoch 81/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.3551 - acc: 0.9333
# Epoch 82/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.3528 - acc: 0.9333
# Epoch 83/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.3491 - acc: 0.9333
# Epoch 84/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.3516 - acc: 0.9524
# Epoch 85/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.3438 - acc: 0.9524
# Epoch 86/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.3439 - acc: 0.9238
# Epoch 87/100
# 105/105 [==============================] - 0s 2ms/step - loss: 0.3400 - acc: 0.9238
# Epoch 88/100
# 105/105 [==============================] - 0s 2ms/step - loss: 0.3376 - acc: 0.9429
# Epoch 89/100
# 105/105 [==============================] - 0s 2ms/step - loss: 0.3375 - acc: 0.9524
# Epoch 90/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.3333 - acc: 0.9429
# Epoch 91/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.3313 - acc: 0.9238
# Epoch 92/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.3293 - acc: 0.9333
# Epoch 93/100
# 105/105 [==============================] - 0s 2ms/step - loss: 0.3268 - acc: 0.9524
# Epoch 94/100
# 105/105 [==============================] - 0s 2ms/step - loss: 0.3224 - acc: 0.9524
# Epoch 95/100
# 105/105 [==============================] - 0s 2ms/step - loss: 0.3219 - acc: 0.9238
# Epoch 96/100
# 105/105 [==============================] - 0s 2ms/step - loss: 0.3185 - acc: 0.9524
# Epoch 97/100
# 105/105 [==============================] - 0s 2ms/step - loss: 0.3159 - acc: 0.9619
# Epoch 98/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.3159 - acc: 0.9333
# Epoch 99/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.3114 - acc: 0.9619
# Epoch 100/100
# 105/105 [==============================] - 0s 1ms/step - loss: 0.3111 - acc: 0.9333
# Accuracy = 0.93

# %% [markdown]
# ## Functional NN

# %%
from keras.layers import Input, Dense
from keras.models import Model
from keras.utils import np_utils
from sklearn.preprocessing import LabelEncoder
from sklearn import datasets
from sklearn.model_selection import train_test_split

iris = datasets.load_iris()
X, y = iris.data, iris.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

y_train_one_hot = np_utils.to_categorical(y_train)
y_test_one_hot = np_utils.to_categorical(y_test)

# print(y_one_hot)

inp = Input(shape=(4,))
x = Dense(16, activation='sigmoid')(inp)
out = Dense(3, activation='softmax')(x)
model = Model(inputs=inp, outputs= out)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=["accuracy"])
model.fit(X_train, y_train_one_hot, epochs=100, batch_size=1, verbose=0);
loss, accuracy = model.evaluate(X_test, y_test_one_hot, verbose=0)
print("Accuracy = {:.2f}".format(accuracy))
# Out:
# Accuracy = 0.98
